# %% [markdown]
# 1. What is python, and why is it popular?
# > Python is a programming language in   which we can use for writting code as input to get the output.
# > Python is the most popular language because its is widely use in data industry, easy to learn, versatility, readable, lots of libraries.
#
# 2. What is an interpreter in Python?
# > Interpreter is a translater which is convert the code to bytecode(human undesatnding language to machine understandig bytecode).
# > We use the .py extension for run and execute the code in python.
#
# 3. What are pre-defined keywords in Python?
# > False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
#
# 4. Can keywords be used as variable names?
# > No, we can't use keywords as variables name.
#
# 5. What is mutability in Python?
# > Mutability means changable, Once we create one object after creating the object if we can be able to change the value of the object then its called mutable object.
# > Example : List
#
# 6. Why are lists mutable, but tuples are immutable?
# > List is a mutable object because we  can change the values of the list even after create the list.
#
#
#
# 7. What is the difference between “==” and “is” operators in Python?
# >
#
# 8.  What are logical operators in Python?
# > Logical  operators are AND, OR, NOT.
# AND : T T  T
#       F T  F
#       T F  F
#       F F  F
# OR :  T T  T
#       F T  T
#       T F  T
#       F F  F
# 9. What is type casting in Python?
# > We can change the one type of varibale to another type is type casting, like int to float, float to int.
#
# 10. What is the difference between implicit and explicit type casting?
# > Implicit is the automatic conversion of a smaller data type to a larger data type and it happnes automatically by compliler, if there is no risk of data loss.
# Ex- int = 1
#     float b=a
#
# > Explicit is the manual conversion of one data type to another using the cast operator and its convert by the programmer.
# Ex- float a = 5.2;
#     int b = (int) a;
#
# 11. What is the purpose of conditional statements in Python?
# > In Python, conditional statements is used to perform decision-making in programs. They allow the code to execute different blocks of code based on whether a condition is true or false.
#
# 12. How does the elif statement work?
# > The elif stands for else if and this statement is used to check multiple conditions in a decision-making structure.
#
#
# 13. What is the difference between for and while loops?
# > Both for and while loop used for repeat a block of code but in different scenarios basis.
#
# 14. Describe a scenario where a while loop is more suitable than a for loop?
# >
